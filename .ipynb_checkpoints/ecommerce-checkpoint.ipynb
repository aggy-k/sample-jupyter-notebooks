# %% [markdown]
# ## From Excel to Python

# %%
import numpy as np
import pandas as pd
pd.set_option('display.float_format', '{:,.2f}'.format)
file = "data/ecommerce.csv"
df = pd.read_csv(file, decimal=',')

# %% [markdown]
# ### Approaching Your Dataset for the First Time

# %% [markdown]
# Explore your dataset quickly using Pandas, before you start your analysis
# - Checking how your dataset looks like
# - Finding out quickly how many columns and rows
# - What are all the column names
# - What data type does each column have
# - etc

# %%
# What data do you have? Print your dataframe
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26      2.55   17,850.00  United Kingdom
# 1        12/1/2010 8:26      3.39   17,850.00  United Kingdom
# 2        12/1/2010 8:26      2.75   17,850.00  United Kingdom
# 3        12/1/2010 8:26      3.39   17,850.00  United Kingdom
# 4        12/1/2010 8:26      3.39   17,850.00  United Kingdom
# ...                 ...       ...         ...             ...
# 541904  12/9/2011 12:50      0.85   12,680.00          France
# 541905  12/9/2011 12:50       2.1   12,680.00          France
# 541906  12/9/2011 12:50      4.15   12,680.00          France
# 541907  12/9/2011 12:50      4.15   12,680.00          France
# 541908  12/9/2011 12:50      4.95   12,680.00          France
#
# [541909 rows x 8 columns]

# %%
# total number of columns & rows in short
df.shape
# Out:
# (541909, 8)

# %%
# All the column names
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
# What data type do the columns have?
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice       object
# CustomerID     float64
# Country         object
# dtype: object

# %%
# describe() is used to generate descriptive statistics of the data in a Pandas DataFrame or Series. 
# It summarizes central tendency and dispersion of the dataset. 
# describe() helps in getting a quick overview of the dataset. 
df.describe()
# Out:
#         Quantity  CustomerID
# count 541,909.00  406,829.00
# mean        9.55   15,287.69
# std       218.08    1,713.60
# min   -80,995.00   12,346.00
# 25%         1.00   13,953.00
# 50%         3.00   15,152.00
# 75%        10.00   16,791.00
# max    80,995.00   18,287.00

# %% [markdown]
# From the quick statistic overview above, does everything make sense?
# Should we explore a few things that bother us about the data 👆?

# %%
# Let's sort the values by Quantity
df.sort_values(by="Quantity", ascending=False)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 502122    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
# 74614     542504     37413                                  NaN      5568
# 421632    573008     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# ...          ...       ...                                  ...       ...
# 4287     C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 225530    556691     23005         printing smudges/thrown away     -9600
# 225529    556690     23005         printing smudges/thrown away     -9600
# 61624    C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 540422   C581484     23843          PAPER CRAFT , LITTLE BIRDIE    -80995
#
#              InvoiceDate UnitPrice  CustomerID         Country
# 540421    12/9/2011 9:15      2.08   16,446.00  United Kingdom
# 61619    1/18/2011 10:01      1.04   12,346.00  United Kingdom
# 502122  11/25/2011 15:57         0   13,256.00  United Kingdom
# 74614    1/28/2011 12:03         0         nan  United Kingdom
# 421632  10/27/2011 12:26      0.21   12,901.00  United Kingdom
# ...                  ...       ...         ...             ...
# 4287     12/2/2010 14:23      0.03   15,838.00  United Kingdom
# 225530   6/14/2011 10:37         0         nan  United Kingdom
# 225529   6/14/2011 10:37         0         nan  United Kingdom
# 61624    1/18/2011 10:17      1.04   12,346.00  United Kingdom
# 540422    12/9/2011 9:27      2.08   16,446.00  United Kingdom
#
# [541909 rows x 8 columns]

# %%
# df["Country"].drop_duplicates().sort_values()
# df[["InvoiceNo", "Quantity", "UnitPrice"]]
# df[["StockCode", "Description"]].drop_duplicates().sort_values(by="Description")
# df[df["Description"].isna()]
df.filter(items=['StockCode', 'Description'])
# Out:
#        StockCode                          Description
# 0         85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1          71053                  WHITE METAL LANTERN
# 2         84406B       CREAM CUPID HEARTS COAT HANGER
# 3         84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4         84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...          ...                                  ...
# 541904     22613          PACK OF 20 SPACEBOY NAPKINS
# 541905     22899         CHILDREN'S APRON DOLLY GIRL
# 541906     23254        CHILDRENS CUTLERY DOLLY GIRL
# 541907     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 541908     22138        BAKING SET 9 PIECE RETROSPOT
#
# [541909 rows x 2 columns]

# %% [markdown]
# ### Cleaning and Manipulating Data

# %% [markdown]
# Unit price seems like something that should be numeric
#
# Let's convert the data type of unit price to float, so we can do some calculation with it 🤔
#
# While, CustomerID can be converted to a non-numerical type, because we don't need to do any calculation with it
#
# 👇👇👇

# %%
# unit price seems like something that should be numeric, let's convert the data type of unit price to float
df['UnitPrice'] = df['UnitPrice'].astype('float')
df['CustomerID'] = df['CustomerID'].astype('object')
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID      object
# Country         object
# dtype: object

# %%
df.describe()
# Out:
#         Quantity  UnitPrice
# count 541,909.00 541,909.00
# mean        9.55       4.61
# std       218.08      96.76
# min   -80,995.00 -11,062.06
# 25%         1.00       1.25
# 50%         3.00       2.08
# 75%        10.00       4.13
# max    80,995.00  38,970.00

# %%
df.sort_values(by="UnitPrice", ascending=True)
# Out:
#        InvoiceNo  StockCode        Description  Quantity       InvoiceDate  \
# 299984   A563187          B    Adjust bad debt         1   8/12/2011 14:52
# 299983   A563186          B    Adjust bad debt         1   8/12/2011 14:51
# 40984     539750      22652  TRAVEL SEWING KIT         1  12/21/2010 15:40
# 52217     540696     84562A                NaN         1    1/11/2011 9:14
# 52262     540699       POST                NaN      1000    1/11/2011 9:32
# ...          ...        ...                ...       ...               ...
# 16356    C537651  AMAZONFEE         AMAZON FEE        -1   12/7/2010 15:49
# 43703    C540118  AMAZONFEE         AMAZON FEE        -1     1/5/2011 9:57
# 43702    C540117  AMAZONFEE         AMAZON FEE        -1     1/5/2011 9:55
# 524602   C580605  AMAZONFEE         AMAZON FEE        -1   12/5/2011 11:36
# 222681   C556445          M             Manual        -1   6/10/2011 15:31
#
#         UnitPrice CustomerID         Country
# 299984 -11,062.06        NaN  United Kingdom
# 299983 -11,062.06        NaN  United Kingdom
# 40984        0.00        NaN  United Kingdom
# 52217        0.00        NaN  United Kingdom
# 52262        0.00        NaN  United Kingdom
# ...           ...        ...             ...
# 16356   13,541.33        NaN  United Kingdom
# 43703   16,453.71        NaN  United Kingdom
# 43702   16,888.02        NaN  United Kingdom
# 524602  17,836.46        NaN  United Kingdom
# 222681  38,970.00  15,098.00  United Kingdom
#
# [541909 rows x 8 columns]

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID             object
# Country                object
# dtype: object

# %%
df_sales_only = (df['Quantity'] >= 0) & (df['UnitPrice'] >= 0) & (df['CustomerID'].notna())
sales = df[df_sales_only]
sales
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# 0      2010-12-01 08:26:00       2.55  17,850.00  United Kingdom
# 1      2010-12-01 08:26:00       3.39  17,850.00  United Kingdom
# 2      2010-12-01 08:26:00       2.75  17,850.00  United Kingdom
# 3      2010-12-01 08:26:00       3.39  17,850.00  United Kingdom
# 4      2010-12-01 08:26:00       3.39  17,850.00  United Kingdom
# ...                    ...        ...        ...             ...
# 541904 2011-12-09 12:50:00       0.85  12,680.00          France
# 541905 2011-12-09 12:50:00       2.10  12,680.00          France
# 541906 2011-12-09 12:50:00       4.15  12,680.00          France
# 541907 2011-12-09 12:50:00       4.15  12,680.00          France
# 541908 2011-12-09 12:50:00       4.95  12,680.00          France
#
# [397924 rows x 8 columns]

# %%
sales.describe()
# Out:
#         Quantity  UnitPrice
# count 397,924.00 397,924.00
# mean       13.02       3.12
# std       180.42      22.10
# min         1.00       0.00
# 25%         2.00       1.25
# 50%         6.00       1.95
# 75%        12.00       3.75
# max    80,995.00   8,142.75

# %%
sales.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID Country
# 541904 2011-12-09 12:50:00       0.85  12,680.00  France
# 541905 2011-12-09 12:50:00       2.10  12,680.00  France
# 541906 2011-12-09 12:50:00       4.15  12,680.00  France
# 541907 2011-12-09 12:50:00       4.15  12,680.00  France
# 541908 2011-12-09 12:50:00       4.95  12,680.00  France

# %%
sales = sales.reset_index()

# %% [markdown]
# ⭐️ Adding a new "calculated" column is super simple ⭐️

# %%
# Now that we have converted UnitPrice to numeric type, we can use it to calculate the invoice amount
amount = (sales['Quantity'] * sales['UnitPrice'])

# %%
sales['Amount'] = amount
sales
# Out:
#          index InvoiceNo StockCode                          Description  \
# 0            0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1            1    536365     71053                  WHITE METAL LANTERN
# 2            2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3            3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4            4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...        ...       ...       ...                                  ...
# 397919  541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 397920  541905    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 397921  541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 397922  541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 397923  541908    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
#         Quantity         InvoiceDate  UnitPrice CustomerID         Country  \
# 0              6 2010-12-01 08:26:00       2.55  17,850.00  United Kingdom
# 1              6 2010-12-01 08:26:00       3.39  17,850.00  United Kingdom
# 2              8 2010-12-01 08:26:00       2.75  17,850.00  United Kingdom
# 3              6 2010-12-01 08:26:00       3.39  17,850.00  United Kingdom
# 4              6 2010-12-01 08:26:00       3.39  17,850.00  United Kingdom
# ...          ...                 ...        ...        ...             ...
# 397919        12 2011-12-09 12:50:00       0.85  12,680.00          France
# 397920         6 2011-12-09 12:50:00       2.10  12,680.00          France
# 397921         4 2011-12-09 12:50:00       4.15  12,680.00          France
# 397922         4 2011-12-09 12:50:00       4.15  12,680.00          France
# 397923         3 2011-12-09 12:50:00       4.95  12,680.00          France
#
#         Amount
# 0        15.30
# 1        20.34
# 2        22.00
# 3        20.34
# 4        20.34
# ...        ...
# 397919   10.20
# 397920   12.60
# 397921   16.60
# 397922   16.60
# 397923   14.85
#
# [397924 rows x 10 columns]

# %%
sales.describe()
# Out:
#            index   Quantity  UnitPrice     Amount
# count 397,924.00 397,924.00 397,924.00 397,924.00
# mean  278,465.22      13.02       3.12      22.39
# std   152,771.37     180.42      22.10     309.06
# min         0.00       1.00       0.00       0.00
# 25%   148,333.75       2.00       1.25       4.68
# 50%   284,907.50       6.00       1.95      11.80
# 75%   410,079.25      12.00       3.75      19.80
# max   541,908.00  80,995.00   8,142.75 168,469.60

# %%
sales['Amount'].sum()
# Out:
# 8911407.904

# %%
sales['Amount'].mean()
# Out:
# 22.39474850474768

# %%
sales['Amount'].value_counts()
# Out:
# 15.00       20082
# 17.70        9174
# 16.50        8490
# 10.20        8028
# 19.80        7625
#             ...
# 65.88           1
# 159.50          1
# 436.80          1
# 1,275.00        1
# 321.84          1
# Name: Amount, Length: 2940, dtype: int64

# %%
sales['Amount'].value_counts().sort_index()
# Out:
# 0.00          40
# 0.00           4
# 0.06           1
# 0.08           1
# 0.10           3
#               ..
# 7,144.72       1
# 8,142.75       1
# 38,970.00      1
# 77,183.60      1
# 168,469.60     1
# Name: Amount, Length: 2940, dtype: int64

# %%
sales['PurchaseType'] = np.where(sales['Amount'] > 70, 'High Value', 'Low Value')
sales
# Out:
#          index InvoiceNo StockCode                          Description  \
# 0            0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1            1    536365     71053                  WHITE METAL LANTERN
# 2            2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3            3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4            4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...        ...       ...       ...                                  ...
# 397919  541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 397920  541905    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 397921  541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 397922  541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 397923  541908    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
#         Quantity         InvoiceDate  UnitPrice CustomerID         Country  \
# 0              6 2010-12-01 08:26:00       2.55  17,850.00  United Kingdom
# 1              6 2010-12-01 08:26:00       3.39  17,850.00  United Kingdom
# 2              8 2010-12-01 08:26:00       2.75  17,850.00  United Kingdom
# 3              6 2010-12-01 08:26:00       3.39  17,850.00  United Kingdom
# 4              6 2010-12-01 08:26:00       3.39  17,850.00  United Kingdom
# ...          ...                 ...        ...        ...             ...
# 397919        12 2011-12-09 12:50:00       0.85  12,680.00          France
# 397920         6 2011-12-09 12:50:00       2.10  12,680.00          France
# 397921         4 2011-12-09 12:50:00       4.15  12,680.00          France
# 397922         4 2011-12-09 12:50:00       4.15  12,680.00          France
# 397923         3 2011-12-09 12:50:00       4.95  12,680.00          France
#
#         Amount PurchaseType
# 0        15.30    Low Value
# 1        20.34    Low Value
# 2        22.00    Low Value
# 3        20.34    Low Value
# 4        20.34    Low Value
# ...        ...          ...
# 397919   10.20    Low Value
# 397920   12.60    Low Value
# 397921   16.60    Low Value
# 397922   16.60    Low Value
# 397923   14.85    Low Value
#
# [397924 rows x 11 columns]

# %%
# more advance IF with multiple conditions:
conditions = [
    (sales['Amount']>=120),
    (sales['Amount']>=50) & (sales['Amount']<120),
    (sales['Amount']<50),
]
values = ['High Value', 'Med Value', 'Low Value']

sales['PurchaseType2'] = np.select(conditions, values)
sales[sales['Amount'] >= 50]
# Out:
#          index InvoiceNo StockCode                          Description  \
# 9            9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT
# 26          26    536370     22728            ALARM CLOCK BAKELIKE PINK
# 27          27    536370     22727            ALARM CLOCK BAKELIKE RED
# 33          33    536370     21035      SET/2 RED RETROSPOT TEA TOWELS
# 34          34    536370     22326  ROUND SNACK BOXES SET OF4 WOODLAND
# ...        ...       ...       ...                                  ...
# 397881  541866    581583     85038      6 CHOCOLATE LOVE HEART T-LIGHTS
# 397882  541867    581584     20832     RED FLOCK LOVE HEART PHOTO FRAME
# 397883  541868    581584     85038      6 CHOCOLATE LOVE HEART T-LIGHTS
# 397907  541892    581586     21217        RED RETROSPOT ROUND CAKE TINS
# 397908  541893    581586     20685                DOORMAT RED RETROSPOT
#
#         Quantity         InvoiceDate  UnitPrice CustomerID         Country  \
# 9             32 2010-12-01 08:34:00       1.69  13,047.00  United Kingdom
# 26            24 2010-12-01 08:45:00       3.75  12,583.00          France
# 27            24 2010-12-01 08:45:00       3.75  12,583.00          France
# 33            18 2010-12-01 08:45:00       2.95  12,583.00          France
# 34            24 2010-12-01 08:45:00       2.95  12,583.00          France
# ...          ...                 ...        ...        ...             ...
# 397881        36 2011-12-09 12:23:00       1.85  13,777.00  United Kingdom
# 397882        72 2011-12-09 12:25:00       0.72  13,777.00  United Kingdom
# 397883        48 2011-12-09 12:25:00       1.85  13,777.00  United Kingdom
# 397907        24 2011-12-09 12:49:00       8.95  13,113.00  United Kingdom
# 397908        10 2011-12-09 12:49:00       7.08  13,113.00  United Kingdom
#
#         Amount PurchaseType PurchaseType2
# 9        54.08    Low Value     Med Value
# 26       90.00   High Value     Med Value
# 27       90.00   High Value     Med Value
# 33       53.10    Low Value     Med Value
# 34       70.80   High Value     Med Value
# ...        ...          ...           ...
# 397881   66.60    Low Value     Med Value
# 397882   51.84    Low Value     Med Value
# 397883   88.80   High Value     Med Value
# 397907  214.80   High Value    High Value
# 397908   70.80   High Value     Med Value
#
# [27233 rows x 12 columns]

# %%
sales['PurchaseType2'].value_counts()
# Out:
# Low Value     370691
# Med Value      17987
# High Value      9246
# Name: PurchaseType2, dtype: int64

# %%
import datetime as dt
sales['Description'] = sales['Description'].str.title()
sales['Year'] = sales['InvoiceDate'].dt.year
sales['Year & Invoice'] = sales['Year'].astype('str').str.cat(sales['InvoiceNo'], sep=" | ")
sales
# Out:
#          index InvoiceNo StockCode                          Description  \
# 0            0    536365    85123A   White Hanging Heart T-Light Holder
# 1            1    536365     71053                  White Metal Lantern
# 2            2    536365    84406B       Cream Cupid Hearts Coat Hanger
# 3            3    536365    84029G  Knitted Union Flag Hot Water Bottle
# 4            4    536365    84029E       Red Woolly Hottie White Heart.
# ...        ...       ...       ...                                  ...
# 397919  541904    581587     22613          Pack Of 20 Spaceboy Napkins
# 397920  541905    581587     22899         Children'S Apron Dolly Girl
# 397921  541906    581587     23254        Childrens Cutlery Dolly Girl
# 397922  541907    581587     23255      Childrens Cutlery Circus Parade
# 397923  541908    581587     22138        Baking Set 9 Piece Retrospot
#
#         Quantity         InvoiceDate  UnitPrice CustomerID         Country  \
# 0              6 2010-12-01 08:26:00       2.55  17,850.00  United Kingdom
# 1              6 2010-12-01 08:26:00       3.39  17,850.00  United Kingdom
# 2              8 2010-12-01 08:26:00       2.75  17,850.00  United Kingdom
# 3              6 2010-12-01 08:26:00       3.39  17,850.00  United Kingdom
# 4              6 2010-12-01 08:26:00       3.39  17,850.00  United Kingdom
# ...          ...                 ...        ...        ...             ...
# 397919        12 2011-12-09 12:50:00       0.85  12,680.00          France
# 397920         6 2011-12-09 12:50:00       2.10  12,680.00          France
# 397921         4 2011-12-09 12:50:00       4.15  12,680.00          France
# 397922         4 2011-12-09 12:50:00       4.15  12,680.00          France
# 397923         3 2011-12-09 12:50:00       4.95  12,680.00          France
#
#         Amount PurchaseType PurchaseType2  Year Year & Invoice
# 0        15.30    Low Value     Low Value  2010  2010 | 536365
# 1        20.34    Low Value     Low Value  2010  2010 | 536365
# 2        22.00    Low Value     Low Value  2010  2010 | 536365
# 3        20.34    Low Value     Low Value  2010  2010 | 536365
# 4        20.34    Low Value     Low Value  2010  2010 | 536365
# ...        ...          ...           ...   ...            ...
# 397919   10.20    Low Value     Low Value  2011  2011 | 581587
# 397920   12.60    Low Value     Low Value  2011  2011 | 581587
# 397921   16.60    Low Value     Low Value  2011  2011 | 581587
# 397922   16.60    Low Value     Low Value  2011  2011 | 581587
# 397923   14.85    Low Value     Low Value  2011  2011 | 581587
#
# [397924 rows x 14 columns]

# %%
sales.dtypes
# Out:
# index                      int64
# InvoiceNo                 object
# StockCode                 object
# Description               object
# Quantity                   int64
# InvoiceDate       datetime64[ns]
# UnitPrice                float64
# CustomerID                object
# Country                   object
# Amount                   float64
# PurchaseType              object
# PurchaseType2             object
# Year                       int64
# Year & Invoice            object
# dtype: object

# %% [markdown]
# ### Analyze Data

# %% [markdown]
# ### Pivot Table like in Excel 💪
# - With pd.pivot_table()
# - pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'], aggfunc=np.sum)
#
# ![image.png](attachment:image.png)

# %%
sales_pvt = pd.pivot_table(sales, index=["Country"], 
               values=['Amount', 'Quantity'], 
               aggfunc={"Amount": np.sum, "Quantity": np.mean}).sort_values('Amount', ascending=False)
sales_pvt = sales_pvt.reset_index()
sales_pvt
# Out:
#                  Country       Amount  Quantity
# 0         United Kingdom 7,308,391.55     12.05
# 1            Netherlands   285,446.34     85.03
# 2                   EIRE   265,545.90     19.41
# 3                Germany   228,867.14     13.19
# 4                 France   209,024.05     13.36
# 5              Australia   138,521.31     71.06
# 6                  Spain    61,577.11     11.25
# 7            Switzerland    56,443.95     16.33
# 8                Belgium    41,196.34     11.44
# 9                 Sweden    38,378.33     80.01
# 10                 Japan    37,416.37     81.05
# 11                Norway    36,165.44     18.04
# 12              Portugal    33,439.89     11.03
# 13               Finland    22,546.08     15.63
# 14             Singapore    21,279.29     23.61
# 15       Channel Islands    20,450.44     12.69
# 16               Denmark    18,955.34     21.67
# 17                 Italy    17,483.24     10.70
# 18                Cyprus    13,590.38     10.36
# 19               Austria    10,198.68     12.26
# 20                Poland     7,334.65     11.16
# 21                Israel     7,221.69     16.31
# 22                Greece     4,760.52     10.74
# 23               Iceland     4,310.00     13.51
# 24                Canada     3,666.38     18.30
# 25                   USA     3,580.39     13.73
# 26                 Malta     2,725.59      8.66
# 27           Unspecified     2,667.07      7.33
# 28  United Arab Emirates     1,902.28     14.44
# 29               Lebanon     1,693.88      8.58
# 30             Lithuania     1,661.06     18.63
# 31    European Community     1,300.25      8.32
# 32                Brazil     1,143.60     11.12
# 33                   RSA     1,002.31      6.07
# 34        Czech Republic       826.74     26.84
# 35               Bahrain       548.40     15.29
# 36          Saudi Arabia       145.92      8.89

# %%
#sales_pvt = pd.pivot_table(sales, values="Amount", index="Country", aggfunc=[np.sum, np.mean]) #.droplevel(level=1)
#sales_pvt.sort_values(by=('sum', 'Amount'), ascending=False) 
#sales_pvt = sales_pvt.columns.droplevel(level=1)
#sales_pvt # .reset_index().droplevel(level=0)

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### Basic Charts & Graphs with matplotlib library

# %%
import matplotlib. pyplot as plt
# %matplotlib inline 
# to show the plot after the code

# %%
sales['Month'] = sales['Year'].astype('str') +  sales['InvoiceDate'].dt.month.astype('int').map('{:02d}'.format)
#sales

# %%
avg_purchase = sales.pivot_table(index="Month", 
                                 values=["Quantity", "Amount"], aggfunc={'Quantity': np.sum, 'Amount': np.mean})
avg_purchase = avg_purchase.sort_values(by="Month", ascending=True) #.head(10) #.set_index("Country")
avg_purchase = avg_purchase.reset_index()

# %%
plt.plot(avg_purchase['Month'], avg_purchase['Quantity'])
plt.xticks(rotation=295)
plt.title('Monthly Trend of $ Sales')
plt.xlabel('Year - Month')
plt.ylabel('Amount $')
plt.show()

# %%
top_10 = sales_pvt.head(10).sort_values(by="Amount")
plt.barh(top_10['Country'], top_10['Amount'])
plt.xticks(rotation=295)
plt.show()
